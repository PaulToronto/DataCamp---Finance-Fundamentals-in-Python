# %% [markdown]
# <a href="https://colab.research.google.com/github/PaulToronto/DataCamp---Finance-Fundamentals-in-Python/blob/main/1_4_Visualization_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.4 - Visualization in Python

# %%
import matplotlib.pyplot as plt
import yfinance as yf
import numpy as np

# %% [markdown]
# ## Plotting with pyplot

# %%
msft = yf.Ticker('MSFT')
msft_2024 = msft.history(period='1y', interval='1mo', start='2024-01-01')

months = msft_2024.index.strftime('%b')
open = msft_2024.Open.values
close = msft_2024.Close.values

plt.plot(months, open, color='dodgerblue', linestyle='dotted', label='open')
plt.plot(months, close, color='red', linestyle='--', label='close')

plt.legend()
plt.xlabel('Month')
plt.ylabel('Dollars')
plt.title('Microsoft (MSFT)')
plt.show()

# %% [markdown]
# ## Scatterplots

# %%
plt.scatter(x=months, y=close, color='red', s=100)
plt.show()

# %% [markdown]
# ## Histograms

# %%
plt.hist(x=close, bins=3, edgecolor='black', color='dodgerblue')
plt.show()

# %% [markdown]
# ## Normalizing Histogram data

# %%
plt.hist(x=close, bins=3, edgecolor='black', color='dodgerblue', density=True)
# Out:
# (array([0.01297976, 0.03028611, 0.00865318]),
#  array([385.03909302, 404.29984538, 423.56059774, 442.8213501 ]),
#  <BarContainer object of 3 artists>)

# %%
n, bins, patches = plt.hist(x=close, bins=3, edgecolor='black', color='dodgerblue', density=True)

bin_widths = np.diff(bins)
print('bin_widths: ' +  str(bin_widths))
area = np.sum(n * bin_widths)
print(f"Total area under histogram: {area}")
# Out:
# bin_widths: [19.26075236 19.26075236 19.26075236]
# Total area under histogram: 1.0

# %%
np.diff([2, 4, 8, 16])
# Out:
# array([2, 4, 8])

# %% [markdown]
# ## Layering histograms

# %%
plt.hist(open, bins=6, density=1, alpha=0.5, label='open')
plt.hist(close, bins=6, density=1, alpha=0.5, label='close')
plt.legend()

plt.show()
